# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
gaussian = lambda x: np.exp(-(x ** 2))
normalize = lambda x: x/np.sum(x)

# %%
n=100

ising = np.random.randint(2, size=(n, n))

# %%
plt.imshow(ising, 'binary')
